# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/Global Health Statistics.csv')

# %%
df
# Out:
#              Country         Disease Name Disease Category Treatment Type  \
# 0              Italy              Malaria      Respiratory     Medication
# 1             France                Ebola        Parasitic        Surgery
# 2             Turkey             COVID-19          Genetic    Vaccination
# 3          Indonesia  Parkinson's Disease       Autoimmune        Surgery
# 4              Italy         Tuberculosis          Genetic     Medication
# ...              ...                  ...              ...            ...
# 999995  Saudi Arabia  Parkinson's Disease       Infectious    Vaccination
# 999996  Saudi Arabia              Malaria      Respiratory        Surgery
# 999997           USA                 Zika      Respiratory        Therapy
# 999998       Nigeria               Asthma          Chronic     Medication
# 999999     Indonesia               Asthma     Neurological        Therapy
#
#        Availability of Vaccines/Treatment  Gender  Year  Prevalence Rate (%)  \
# 0                                      No    Male  2013                 0.95
# 1                                     Yes    Male  2002                12.46
# 2                                     Yes    Male  2015                 0.91
# 3                                     Yes   Other  2011                 4.68
# 4                                     Yes    Male  2013                 0.83
# ...                                   ...     ...   ...                  ...
# 999995                                Yes  Female  2021                 4.56
# 999996                                 No  Female  2013                 0.26
# 999997                                 No   Other  2016                13.44
# 999998                                Yes  Female  2020                 1.96
# 999999                                Yes   Other  2004                15.58
#
#         Incidence Rate (%)  Mortality Rate (%)  ... Healthcare Access (%)  \
# 0                     1.55                8.42  ...                 57.74
# 1                     8.63                8.75  ...                 89.21
# 2                     2.35                6.22  ...                 56.41
# 3                     6.29                3.99  ...                 85.20
# 4                    13.59                7.01  ...                 67.00
# ...                    ...                 ...  ...                   ...
# 999995                4.83                9.65  ...                 88.78
# 999996                1.76                0.56  ...                 82.24
# 999997               14.13                1.91  ...                 71.46
# 999998               14.56                4.98  ...                 57.10
# 999999                9.84                0.51  ...                 77.57
#
#         Doctors per 1000  Hospital Beds per 1000  \
# 0                   3.34                    7.58
# 1                   1.33                    5.11
# 2                   4.07                    3.49
# 3                   3.18                    8.44
# 4                   4.61                    5.90
# ...                  ...                     ...
# 999995              1.98                    4.23
# 999996              1.28                    6.34
# 999997              4.18                    8.11
# 999998              2.61                    6.91
# 999999              2.10                    6.79
#
#         Average Treatment Cost (USD)  Recovery Rate (%)  DALYs  \
# 0                              21064              91.82   4493
# 1                              47851              76.65   2366
# 2                              27834              98.55     41
# 3                                144              67.35   3201
# 4                               8908              50.06   2832
# ...                              ...                ...    ...
# 999995                          4528              92.11   1024
# 999996                         20686              84.47    202
# 999997                         18807              86.81   3338
# 999998                         21033              62.15   4806
# 999999                           505              77.23   3241
#
#         Improvement in 5 Years (%)  Per Capita Income (USD)  Education Index  \
# 0                             2.16                    16886             0.79
# 1                             4.82                    80639             0.74
# 2                             5.81                    12245             0.41
# 3                             2.22                    49336             0.49
# 4                             6.93                    47701             0.50
# ...                            ...                      ...              ...
# 999995                        3.88                    29335             0.75
# 999996                        7.95                    30752             0.47
# 999997                        7.31                    62897             0.72
# 999998                        3.82                    98189             0.51
# 999999                        1.11                    79640             0.42
#
#         Urbanization Rate (%)
# 0                       86.02
# 1                       45.52
# 2                       40.20
# 3                       58.47
# 4                       48.14
# ...                       ...
# 999995                  27.94
# 999996                  77.66
# 999997                  46.90
# 999998                  34.73
# 999999                  78.51
#
# [1000000 rows x 22 columns]

# %%
gender = {'Male' : 0, 'Female': 2, 'Other': 3}

# %%
df.Gender = [gender[item] for item in df.Gender]

# %%
df.columns
# Out:
# Index(['Country', 'Disease Name', 'Disease Category', 'Treatment Type',
#        'Availability of Vaccines/Treatment', 'Gender', 'Year',
#        'Prevalence Rate (%)', 'Incidence Rate (%)', 'Mortality Rate (%)',
#        'Age Group', 'Population Affected', 'Healthcare Access (%)',
#        'Doctors per 1000', 'Hospital Beds per 1000',
#        'Average Treatment Cost (USD)', 'Recovery Rate (%)', 'DALYs',
#        'Improvement in 5 Years (%)', 'Per Capita Income (USD)',
#        'Education Index', 'Urbanization Rate (%)'],
#       dtype='object')

# %%
df["Age Group"].unique()
# Out:
# array(['0-18', '61+', '36-60', '19-35'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
df.to_csv('Real_Health.csv')
